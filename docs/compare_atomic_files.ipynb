# %% [markdown]
# # Compare atomic files
#
# This notebook shows how to compare the attributes `levels_prepared` and `lines_prepared` of the atomic files generated by Carsus.

# %%
# Hidden cell for nbsphinx (check cell metadata)
import warnings

warnings.simplefilter('ignore')

# %%
import pandas as pd
from carsus.util import parse_selected_species

# %% [markdown]
# ## Choose files to compare

# %%
path_a = 'kurucz_H-Zn_chianti_H-He_sql.h5'
path_b = 'kurucz_H-Zn_chianti_H-He_pandas.h5'

# %% [markdown]
# ## Define functions

# %%
def highlight_values(val):
    if val == True:
        return 'background-color: #BCF5A9'
    else:
        return 'background-color: #F5A9A9'
    
def highlight_diff(val):
    if val == 0:
        return 'background-color: #BCF5A9'
    else:
        return 'background-color: #F5A9A9'

# %%
def compare_levels_lines(path_a, path_b, ions='H-Zn'):
    
    # Read data
    levels_a = pd.read_hdf(path_a, key='levels')
    levels_b = pd.read_hdf(path_b, key='levels')
    lines_a = pd.read_hdf(path_a, key='lines')
    lines_b = pd.read_hdf(path_b, key='lines')
    
    # Get ions list
    ions = parse_selected_species(ions)
    
    lvl_eq = []
    lns_eq = []
    for ion in ions:
        
        # How many levels per ion in A
        try:
            num_lvl_a = len(levels_a.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lvl_a = 0
            
        # How many levels per ion in B
        try:
            num_lvl_b = len(levels_b.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lvl_b = 0

        # If level number is the same in A and B (and not zero) 
        # then compare cell against cell. `True` means all cells 
        # are equal in both dataframes.
        if num_lvl_a == num_lvl_b:
            val_lvl = True
            
            if num_lvl_a != 0:
                try:
                    k = levels_a.loc[ion].eq(levels_b.loc[ion]).sum().sum()
                    if num_lvl_a*3 != k:  # x3 because this df has three columns!
                        val_lvl = False
                        
                except (KeyError, TypeError, ValueError):
                    pass

        else:
            val_lvl = False
            
        # Append the results
        lvl_eq.append((ion, num_lvl_a, num_lvl_b, val_lvl))
        
        
        # Same for lines
        try:
            num_lns_a = len(lines_a.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lns_a = 0
            
        try:
            num_lns_b = len(lines_a.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lns_b = 0

        if num_lns_a == num_lns_b:
            val_lns = True
            
            if num_lns_a != 0:
                try:
                    k = lines_a.loc[ion].eq(lines_b.loc[ion]).sum().sum()
                    if num_lns_a*8 != k:
                        val_lvl = False
            
                except (KeyError, TypeError, ValueError):
                    pass
            
        else:
            val_lns = False
        
        lns_eq.append((ion, num_lns_a, num_lns_b, val_lns))
            
    df_lvl = pd.DataFrame(lvl_eq, columns=['ion', 'num_lvl_a', 
                                           'num_lvl_b', 'val_lvl'])
    df_lns = pd.DataFrame(lns_eq, columns=['ion', 'num_lns_a', 
                                           'num_lns_b', 'val_lns'])
    df = pd.merge(df_lvl, df_lns).set_index('ion')
    
    df['diff_lvl'] = abs(df['num_lvl_b'] - df['num_lvl_a'])
    df['diff_lns'] = abs(df['num_lns_b'] - df['num_lns_a'])
    df = df[['num_lvl_a', 'num_lvl_b', 'diff_lvl', 'val_lvl', 
          'num_lns_a', 'num_lns_b', 'diff_lns', 'val_lns']]

    return df

# %%
def lvl_diff(path_a, path_b, ion):
    
    # Read data
    levels_a = pd.read_hdf(path_a, key='levels').loc[ion]
    levels_b = pd.read_hdf(path_b, key='levels').loc[ion]
    
    df = levels_a.join(levels_b, how='outer', lsuffix='_a', rsuffix='_b')
    df['energy_diff'] = abs(df['energy_b'] - df['energy_a'])
    df.loc[df['g_a'] == df['g_b'], 'g_values'] = True
    df.loc[df['g_a'] != df['g_b'], 'g_values'] = False
    df.loc[df['metastable_a'] == df['metastable_b'], 'metastable_values'] = True
    df.loc[df['metastable_a'] != df['metastable_b'], 'metastable_values'] = False
    df = df[['energy_a', 'energy_b', 'energy_diff', 'g_a', 'g_b', 'g_values',
             'metastable_a', 'metastable_b', 'metastable_values']]

    return df

# %% [markdown]
# ## Summary and test table

# %%
tt = compare_levels_lines(path_a, path_b)
summary = pd.DataFrame(tt.sum().astype(int), columns=['Total'])

# %%
summary
# Out:
#             Total
# num_lvl_a   24537
# num_lvl_b   24538
# diff_lvl        1
# val_lvl       464
# num_lns_a  271771
# num_lns_b  271771
# diff_lns        0
# val_lns       465

# %% [markdown]
# - **num_???:** _(int)_ total number of levels/lines.
# - **diff_???:** _(int)_ difference in total number of levels/lines between A and B.
# - **val_???:** _(bool)_ means every single cell in dataframe A is equal to the one on B.

# %%
tt.style.applymap(highlight_values, subset=['val_lvl', 'val_lns']).applymap(
    highlight_diff, subset=['diff_lvl', 'diff_lns'])
# Out:
# <style  type="text/css" >
#     #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row0_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row0_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row0_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row0_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row1_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row1_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row1_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row1_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row2_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row2_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row2_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row2_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row3_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row3_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row3_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row3_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row4_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row4_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row4_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row4_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row5_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row5_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row5_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row5_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row6_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row6_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row6_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row6_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row7_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row7_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row7_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row7_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row8_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row8_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row8_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row8_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row9_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row9_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row9_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row9_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row10_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row10_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row10_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row10_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row11_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row11_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row11_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row11_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row12_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row12_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row12_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row12_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row13_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row13_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row13_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row13_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row14_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row14_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row14_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row14_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row15_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row15_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row15_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row15_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row16_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row16_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row16_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row16_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row17_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row17_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row17_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row17_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row18_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row18_col3 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row18_col6 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83dd46c2c53row18_col7 {
#             background-color:  #BCF5A9;
#         }    #T_a6fc1c90_8313_11ea_ab2d_c83

# %% [markdown]
# ## Check specific ion levels
#
# This function is especially useful when you have the same number of levels for a specific ion and `val_lvl` is `False`. Otherwise the color scheme could be confusing, so focus on the energy values.

# %%
ion = (18,1)

# %%
lvl_diff(path_a, path_b, ion).style.applymap(
    highlight_diff, subset=['energy_diff']).applymap(
        highlight_values, subset=['g_values', 'metastable_values'])
# Out:
# <style  type="text/css" >
#     #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row0_col2 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row0_col5 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row0_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row1_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row1_col5 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row1_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row2_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row2_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row2_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row3_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row3_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row3_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row4_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row4_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row4_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row5_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row5_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row5_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row6_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row6_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row6_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row7_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row7_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row7_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row8_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row8_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row8_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row9_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row9_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row9_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row10_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row10_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row10_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row11_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row11_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row11_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row12_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row12_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row12_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row13_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row13_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row13_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row14_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row14_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row14_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row15_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row15_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row15_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row16_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row16_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row16_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row17_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row17_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row17_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row18_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row18_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row18_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row19_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row19_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row19_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row20_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row20_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row20_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row21_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row21_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row21_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row22_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row22_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row22_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row23_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row23_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row23_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row24_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row24_col5 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row24_col8 {
#             background-color:  #BCF5A9;
#         }    #T_a77256d0_8313_11ea_ab2d_c83dd46c2c53row25_col2 {
#             background-color:  #F5A9A9;
#         }    #T_a77256d0_8313_11e
