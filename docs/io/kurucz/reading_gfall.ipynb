# %% [markdown]
# ### Reading the GFALL Kurucz file ###

# %%
from carsus.io.kurucz import GFALLReader

# %% [markdown]
# Download gfall.dat from http://kurucz.harvard.edu/linelists/gfall/

# %%
gfall_reader = GFALLReader('gfall.dat')
# Out:
# [carsus.io.kurucz.gfall][WARNING]  A specific combination to identify unique levels from the gfall data has not been given. Defaulting to ["energy", "j"]. (gfall.py:68)

# %% [markdown]
# We now show how to sequentially read the gfall data. Accessing the individual attributes `.levels` will run the functions (e.g. `extract_levels`) and store the resulting dataframes in the object.

# %%
gfall_reader.gfall_raw
# Out:
# [carsus.io.kurucz.gfall][INFO   ]  Parsing GFALL gfall.dat (gfall.py:116)
#          wavelength  loggf  element_code     e_first  j_first  blank1  \
# 2            2.4898 -0.842          7.05       0.000      0.0     NaN
# 3            2.8787 -0.171          7.05       0.000      0.0     NaN
# 4            5.2682 -0.870          5.03       0.000      0.0     NaN
# 5            6.0313 -0.215          5.03       0.000      0.0     NaN
# 6            6.1092 -5.150          5.03       0.000      0.0     NaN
# 7            6.3177 -2.360         15.05       0.000      0.0     NaN
# 8            6.3450 -2.060         15.05       0.000      0.0     NaN
# 9            6.6772 -0.790         14.05       0.000      1.5     NaN
# 10           6.9121 -1.940         15.05       0.000      0.0     NaN
# 11           6.9204 -0.460         14.05       0.000      1.5     NaN
# 12           6.9236 -0.430         14.05       0.000      1.5     NaN
# ...

# %%
gfall_reader.gfall
# Out:
#         wavelength  loggf  blank1  blank2  log_gamma_rad  log_gamma_stark  \
# 2           2.4898 -0.842     NaN     NaN          11.73             0.00
# 3           2.8787 -0.171     NaN     NaN          12.26             0.00
# 4           5.2682 -0.870     NaN     NaN           0.00             0.00
# 5           6.0313 -0.215     NaN     NaN           0.00             0.00
# 6           6.1092 -5.150     NaN     NaN           0.00             0.00
# 7           6.3177 -2.360     NaN     NaN           0.00             0.00
# 8           6.3450 -2.060     NaN     NaN           0.00             0.00
# 9           6.6772 -0.790     NaN     NaN           0.00             0.00
# 10          6.9121 -1.940     NaN     NaN           0.00             0.00
# 11          6.9204 -0.460     NaN     NaN           0.00             0.00
# 12          6.9236 -0.430     NaN     NaN           0.00             0.00
# 13          6.9448 -1.150     NaN     NaN           0.00             0.00
# ...

# %%
gfall_reader.levels
# Out:
#                                           energy    j     label method
# atomic_number ion_charge level_index
# 2             0          0                 0.000  0.0     s2 1S   meas
#                          1            159856.069  1.0     2s 3S   meas
#                          2            166277.546  0.0     2s 1S   meas
#                          3            169086.864  2.0     2p 3P   meas
#                          4            169086.940  1.0     2p 3P   meas
#                          5            169087.007  2.0     2p 3P   meas
#                          6            169087.008  4.0  2p 3P av   meas
#                          7            169087.928  0.0     2p 3P   meas
#                          8            171135.000  1.0     2p 1P   meas
#                          9            183236.892  1.0     3s 3S   meas
#                          10           184864.936  0.0     3s 1S   meas
#                          11           185564.654  2.0     3p 3P   meas
# ...

# %%
gfall_reader.lines
# Out:
# [carsus.io.kurucz.gfall][INFO   ]  Extracting line data: atomic_number, ion_charge, energy_lower, j_lower, energy_upper, j_upper, wavelength, loggf (gfall.py:292)
#                                                               energy_upper  \
# atomic_number ion_charge level_index_lower level_index_upper
# 7             5          0                 14                  4016390.000
#                                            6                   3473790.000
# 5             3          0                 9                   1898180.000
#                                            6                   1658020.000
#                                            3                   1636882.000
# 15            5          0                 9                   1582860.000
#                                            8                   1576040.000
# 14            5          0                 36                  1497630.000
# ...
