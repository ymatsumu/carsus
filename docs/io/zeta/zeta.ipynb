# %%
# Hidden cell (check metadata)
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Knox Long's recombination zeta

# %% [markdown]
# ## Straight to HDF5
#
# To bypass the creation and ingestion of the SQL database described in the **Quickstart guide** you can make use of the `KnoxLongZeta` class.

# %%
import pandas as pd
from carsus.io.zeta import KnoxLongZeta

# %%
zeta = KnoxLongZeta('./carsus/data/knox_long_recombination_zeta.dat')

# %%
zeta.base
# Out:
# temp                      2000.0   4000.0   6000.0   8000.0   10000.0  \
# atomic_number ion_charge
# 1             1            0.3390   0.3846   0.4132   0.4338   0.4498
#               2            0.0000   0.0000   0.0000   0.0000   0.0000
# 2             1            0.4012   0.4669   0.5073   0.5363   0.5587
#               2            0.2660   0.2993   0.3220   0.3395   0.3538
#               3            0.0000   0.0000   0.0000   0.0000   0.0000
# 3             1            0.2044   0.2549   0.2923   0.3218   0.3459
#               2            0.2110   0.2429   0.2664   0.2854   0.3013
#               3            0.2348   0.2607   0.2788   0.2931   0.3050
# 4             1            0.5261   0.5975   0.6408   0.6713   0.6946
#               2            0.1851   0.2011   0.2171   0.2318   0.2452
#               3            0.1745   0.1904   0.2035   0.2147   0.2248
#               4            0.2159   0.2377   0.2528   0.2648   0.2749
# ...

# %% [markdown]
# Dump the data with the `to_hdf` method.

# %%
zeta.to_hdf('test.h5')
